# %% [markdown]
# # Base Neural Network
# How does CLIP compare to other Neural Network Models for Image Classification?

# %%
import os

image_dir = "data/"
all_images = [x for x in os.listdir(image_dir) if x.endswith('.jpg')]
categories = set([x[:-8] for x in all_images])
category2images = {category : [] for category in categories}
for img in all_images:
    category2images[img[:-8]].append(img)

all_images
# Out:
# ['bagel000.jpg',
#  'bagel001.jpg',
#  'bagel002.jpg',
#  'bagel003.jpg',
#  'bagel004.jpg',
#  'bagel005.jpg',
#  'bagel006.jpg',
#  'bagel007.jpg',
#  'bagel008.jpg',
#  'bagel009.jpg',
#  'bagel010.jpg',
#  'bagel011.jpg',
#  'bagel012.jpg',
#  'bagel013.jpg',
#  'bagel014.jpg',
#  'bagel015.jpg',
#  'bagel016.jpg',
#  'bagel017.jpg',
#  'bagel018.jpg',
#  'bagel019.jpg',
#  'bagel020.jpg',
#  'bagel021.jpg',
#  'bagel022.jpg',
#  'bagel023.jpg',
#  'bagel024.jpg',
#  'bagel025.jpg',
#  'bagel026.jpg',
#  'bagel027.jpg',
#  'bagel028.jpg',
#  'bagel029.jpg',
#  'bagel030.jpg',
#  'bagel031.jpg',
#  'bagel032.jpg',
#  'bagel033.jpg',
#  'bagel034.jpg',
#  'bagel035.jpg',
#  'bagel036.jpg',
#  'bagel037.jpg',
#  'bagel038.jpg',
#  'bagel039.jpg',
#  'bagel040.jpg',
#  'bagel041.jpg',
#  'bagel042.jpg',
#  'bagel043.jpg',
#  'bagel044.jpg',
#  'bagel045.jpg',
#  'bagel046.jpg',
#  'bagel047.jpg',
#  'bagel048.jpg',
#  'bagel049.jpg',
#  'bagel050.jpg',
#  'bagel051.jpg',
#  'bagel052.jpg',
#  'bagel053.jpg',
#  'bagel054.jpg',
#  'bagel055.jpg',
#  'bagel056.jpg',
#  'bagel057.jpg',
#  'bagel058.jpg',
#  'bagel059.jpg',
#  'bagel060.jpg',
#  'bagel061.jpg',
#  'bagel062.jpg',
#  'bagel063.jpg',
#  'bagel064.jpg',
#  'bagel065.jpg',
#  'bagel066.jpg',
#  'bagel067.jpg',
#  'bagel068.jpg',
#  'bagel069.jpg',
#  'bagel070.jpg',
#  'bagel071.jpg',
#  'bagel072.jpg',
#  'bagel073.jpg',
#  'bagel074.jpg',
#  'bagel075.jpg',
#  'bagel076.jpg',
#  'bagel077.jpg',
#  'bagel078.jpg',
#  'bagel079.jpg',
#  'bagel080.jpg',
#  'bagel081.jpg',
#  'bagel082.jpg',
#  'bagel083.jpg',
#  'bagel084.jpg',
#  'bagel085.jpg',
#  'bagel086.jpg',
#  'bagel087.jpg',
#  'bagel088.jpg',
#  'bagel089.jpg',
#  'bagel090.jpg',
#  'bagel091.jpg',
#  'bagel092.jpg',
#  'bagel093.jpg',
#  'bagel094.jpg',
#  'bagel095.jpg',
#  'bagel096.jpg',
#  'bagel097.jpg',
#  'bagel098.jpg',
#  'bagel099.jpg',
#  'bagel100.jpg',
#  'bagel101.jpg',
#  'bagel102.jpg',
#  'bagel103.jpg',
#  'bagel104.jpg',
#  'bagel105.jpg',
#  'bagel106.jpg',
#  'bagel107.jpg',
#  'bagel108.jpg',
#  'bagel109.jpg',
#  'bagel110.jpg',
#  'bagel111.jpg',
#  'bagel112.jpg',
#  'bagel113.jpg',
#  'bagel114.jpg',
#  'bagel115.jpg',
#  'bagel116.jpg',
#  'bagel117.jpg',
#  'bagel118.jpg',
#  'bagel119.jpg',
#  'bagel120.jpg',
#  'bagel121.jpg',
#  'bagel122.jpg',
#  'bagel123.jpg',
#  'bagel124.jpg',
#  'banana000.jpg',
#  'banana001.jpg',
#  'banana002.jpg',
#  'banana003.jpg',
#  'banana004.jpg',
#  'banana005.jpg',
#  'banana006.jpg',
#  'banana007.jpg',
#  'banana008.jpg',
#  'banana009.jpg',
#  'banana010.jpg',
#  'banana011.jpg',
#  'banana012.jpg',
#  'banana013.jpg',
#  'banana014.jpg',
#  'banana015.jpg',
#  'banana016.jpg',
#  'banana017.jpg',
#  'banana018.jpg',
#  'banana019.jpg',
#  'banana020.jpg',
#  'banana021.jpg',
#  'banana022.jpg',
#  'banana023.jpg',
#  'banana024.jpg',
#  'banana025.jpg',
#  'banana026.jpg',
#  'banana027.jpg',
#  'banana028.jpg',
#  'banana029.jpg',
#  'banana030.jpg',
#  'banana031.jpg',
#  'banana032.jpg',
#  'banana033.jpg',
#  'banana034.jpg',
#  'banana035.jpg',
#  'banana036.jpg',
#  'banana037.jpg',
#  'banana038.jpg',
#  'banana039.jpg',
#  'banana040.jpg',
#  'banana041.jpg',
#  'banana042.jpg',
#  'banana043.jpg',
#  'banana044.jpg',
#  'banana045.jpg',
#  'banana046.jpg',
#  'banana047.jpg',
#  'banana048.jpg',
#  'banana049.jpg',
#  'banana050.jpg',
#  'banana051.jpg',
#  'banana052.jpg',
#  'banana053.jpg',
#  'banana054.jpg',
#  'banana055.jpg',
#  'banana056.jpg',
#  'banana057.jpg',
#  'banana058.jpg',
#  'banana059.jpg',
#  'banana060.jpg',
#  'banana061.jpg',
#  'banana062.jpg',
#  'banana063.jpg',
#  'banana064.jpg',
#  'banana065.jpg',
#  'banana066.jpg',
#  'banana067.jpg',
#  'banana068.jpg',
#  'banana069.jpg',
#  'banana070.jpg',
#  'banana071.jpg',
#  'banana072.jpg',
#  'banana073.jpg',
#  'banana074.jpg',
#  'banana075.jpg',
#  'banana076.jpg',
#  'banana077.jpg',
#  'banana078.jpg',
#  'banana079.jpg',
#  'banana080.jpg',
#  'banana081.jpg',
#  'banana082.jpg',
#  'banana083.jpg',
#  'banana084.jpg',
#  'banana085.jpg',
#  'banana086.jpg',
#  'banana087.jpg',
#  'banana088.jpg',
#  'banana089.jpg',
#  'banana090.jpg',
#  'banana091.jpg',
#  'banana092.jpg',
#  'banana093.jpg',
#  'banana094.jpg',
#  'banana095.jpg',
#  'banana096.jpg',
#  'banana097.jpg',
#  'banana098.jpg',
#  'banana099.jpg',
#  'banana100.jpg',
#  'banana101.jpg',
#  'banana102.jpg',
#  'banana103.jpg',
#  'banana104.jpg',
#  'banana105.jpg',
#  'banana106.jpg',
#  'banana107.jpg',
#  'banana108.jpg',
#  'banana109.jpg',
#  'banana110.jpg',
#  'banana111.jpg',
#  'banana112.jpg',
#  'banana113.jpg',
#  'banana114.jpg',
#  'banana115.jpg',
#  'banana116.jpg',
#  'banana117.jpg',
#  'banana118.jpg',
#  'banana119.jpg',
#  'banana120.jpg',
#  'banana121.jpg',
#  'banana122.jpg',
#  'banana123.jpg',
#  'banana124.jpg',
#  'broccoli000.jpg',
#  'broccoli001.jpg',
#  'broccoli002.jpg',
#  'broccoli003.jpg',
#  'broccoli004.jpg',
#  'broccoli005.jpg',
#  'broccoli006.jpg',
#  'broccoli007.jpg',
#  'broccoli008.jpg',
#  'broccoli009.jpg',
#  'broccoli010.jpg',
#  'broccoli011.jpg',
#  'broccoli012.jpg',
#  'broccoli013.jpg',
#  'broccoli014.jpg',
#  'broccoli015.jpg',
#  'broccoli016.jpg',
#  'broccoli017.jpg',
#  'broccoli018.jpg',
#  'broccoli019.jpg',
#  'broccoli020.jpg',
#  'broccoli021.jpg',
#  'broccoli022.jpg',
#  'broccoli023.jpg',
#  'broccoli024.jpg',
#  'broccoli025.jpg',
#  'broccoli026.jpg',
#  'broccoli027.jpg',
#  'broccoli028.jpg',
#  'broccoli029.jpg',
#  'broccoli030.jpg',
#  'broccoli031.jpg',
#  'broccoli032.jpg',
#  'broccoli033.jpg',
#  'broccoli034.jpg',
#  'broccoli035.jpg',
#  'broccoli036.jpg',
#  'broccoli037.jpg',
#  'broccoli038.jpg',
#  'broccoli039.jpg',
#  'broccoli040.jpg',
#  'broccoli041.jpg',
#  'broccoli042.jpg',
#  'broccoli043.jpg',
#  'broccoli044.jpg',
#  'broccoli045.jpg',
#  'broccoli046.jpg',
#  'broccoli047.jpg',
#  'broccoli048.jpg',
#  'broccoli049.jpg',
#  'broccoli050.jpg',
#  'broccoli051.jpg',
#  'broccoli052.jpg',
#  'broccoli053.jpg',
#  'broccoli054.jpg',
#  'broccoli055.jpg',
#  'broccoli056.jpg',
#  'broccoli057.jpg',
#  'broccoli058.jpg',
#  'broccoli059.jpg',
#  'broccoli060.jpg',
#  'broccoli061.jpg',
#  'broccoli062.jpg',
#  'broccoli063.jpg',
#  'broccoli064.jpg',
#  'broccoli065.jpg',
#  'broccoli066.jpg',
#  'broccoli067.jpg',
#  'broccoli068.jpg',
#  'broccoli069.jpg',
#  'broccoli070.jpg',
#  'broccoli071.jpg',
#  'broccoli072.jpg',
#  'broccoli073.jpg',
#  'broccoli074.jpg',
#  'broccoli075.jpg',
#  'broccoli076.jpg',
#  'broccoli077.jpg',
#  'broccoli078.jpg',
#  'broccoli079.jpg',
#  'broccoli080.jpg',
#  'broccoli081.jpg',
#  'broccoli082.jpg',
#  'broccoli083.jpg',
#  'broccoli084.jpg',
#  'broccoli085.jpg',
#  'broccoli086.jpg',
#  'broccoli087.jpg',
#  'broccoli088.jpg',
#  'broccoli089.jpg',
#  'broccoli090.jpg',
#  'broccoli091.jpg',
#  'broccoli092.jpg',
#  'broccoli093.jpg',
#  'broccoli094.jpg',
#  'broccoli095.jpg',
#  'broccoli096.jpg',
#  'broccoli097.jpg',
#  'broccoli098.jpg',
#  'broccoli099.jpg',
#  'broccoli100.jpg',
#  'broccoli101.jpg',
#  'broccoli102.jpg',
#  'broccoli103.jpg',
#  'broccoli104.jpg',
#  'broccoli105.jpg',
#  'broccoli106.jpg',
#  'broccoli107.jpg',
#  'broccoli108.jpg',
#  'broccoli109.jpg',
#  'broccoli110.jpg',
#  'broccoli111.jpg',
#  'broccoli112.jpg',
#  'broccoli113.jpg',
#  'broccoli114.jpg',
#  'broccoli115.jpg',
#  'broccoli116.jpg',
#  'broccoli117.jpg',
#  'broccoli118.jpg',
#  'broccoli119.jpg',
#  'broccoli120.jpg',
#  'broccoli121.jpg',
#  'broccoli122.jpg',
#  'broccoli123.jpg',
#  'broccoli124.jpg',
#  'broccoli125.jpg',
#  'burrito000.jpg',
#  'burrito001.jpg',
#  'burrito002.jpg',
#  'burrito003.jpg',
#  'burrito004.jpg',
#  'burrito005.jpg',
#  'burrito006.jpg',
#  'burrito007.jpg',
#  'burrito008.jpg',
#  'burrito009.jpg',
#  'burrito010.jpg',
#  'burrito011.jpg',
#  'burrito012.jpg',
#  'burrito013.jpg',
#  'burrito014.jpg',
#  'burrito015.jpg',
#  'burrito016.jpg',
#  'burrito017.jpg',
#  'burrito018.jpg',
#  'burrito019.jpg',
#  'burrito020.jpg',
#  'burrito021.jpg',
#  'burrito022.jpg',
#  'burrito023.jpg',
#  'burrito024.jpg',
#  'burrito025.jpg',
#  'burrito026.jpg',
#  'burrito027.jpg',
#  'burrito028.jpg',
#  'burrito029.jpg',
#  'burrito030.jpg',
#  'burrito031.jpg',
#  'burrito032.jpg',
#  'burrito033.jpg',
#  'burrito034.jpg',
#  'burrito035.jpg',
#  'burrito036.jpg',
#  'burrito037.jpg',
#  'burrito038.jpg',
#  'burrito039.jpg',
#  'burrito040.jpg',
#  'burrito041.jpg',
#  'burrito042.jpg',
#  'burrito043.jpg',
#  'burrito044.jpg',
#  'burrito045.jpg',
#  'burrito046.jpg',
#  'burrito047.jpg',
#  'burrito048.jpg',
#  'burrito049.jpg',
#  'burrito050.jpg',
#  'burrito051.jpg',
#  'burrito052.jpg',
#  'burrito053.jpg',
#  'burrito054.jpg',
#  'burrito055.jpg',
#  'burrito056.jpg',
#  'burrito057.jpg',
#  'burrito058.jpg',
#  'burrito059.jpg',
#  'burrito060.jpg',
#  'burrito061.jpg',
#  'burrito062.jpg',
#  'burrito063.jpg',
#  'burrito064.jpg',
#  'burrito065.jpg',
#  'burrito066.jpg',
#  'burrito067.jpg',
#  'burrito068.jpg',
#  'burrito069.jpg',
#  'burrito070.jpg',
#  'burrito071.jpg',
#  'burrito072.jpg',
#  'burrito073.jpg',
#  'burrito074.jpg',
#  'burrito075.jpg',
#  'burrito076.jpg',
#  'burrito077.jpg',
#  'burrito078.jpg',
#  'burrito079.jpg',
#  'burrito080.jpg',
#  'burrito081.jpg',
#  'burrito082.jpg',
#  'burrito083.jpg',
#  'burrito084.jpg',
#  'burrito085.jpg',
#  'burrito086.jpg',
#  'burrito087.jpg',
#  'burrito088.jpg',
#  'burrito089.jpg',
#  'burrito090.jpg',
#  'burrito091.jpg',
#  'burrito092.jpg',
#  'burrito093.jpg',
#  'burrito094.jpg',
#  'burrito095.jpg',
#  'burrito096.jpg',
#  'burrito097.jpg',
#  'burrito098.jpg',
#  'burrito099.jpg',
#  'burrito100.jpg',
#  'burrito101.jpg',
#  'burrito102.jpg',
#  'burrito103.jpg',
#  'burrito104.jpg',
#  'burrito105.jpg',
#  'burrito106.jpg',
#  'burrito107.jpg',
#  'burrito108.jpg',
#  'burrito109.jpg',
#  'burrito110.jpg',
#  'burrito111.jpg',
#  'burrito112.jpg',
#  'burrito113.jpg',
#  'burrito114.jpg',
#  'burrito115.jpg',
#  'burrito116.jpg',
#  'burrito117.jpg',
#  'burrito118.jpg',
#  'burrito119.jpg',
#  'burrito120.jpg',
#  'burrito121.jpg',
#  'burrito122.jpg',
#  'burrito123.jpg',
#  'burrito124.jpg',
#  'cabbage000.jpg',
#  'cabbage001.jpg',
#  'cabbage002.jpg',
#  'cabbage003.jpg',
#  'cabbage004.jpg',
#  'cabbage005.jpg',
#  'cabbage006.jpg',
#  'cabbage007.jpg',
#  'cabbage008.jpg',
#  'cabbage009.jpg',
#  'cabbage010.jpg',
#  'cabbage011.jpg',
#  'cabbage012.jpg',
#  'cabbage013.jpg',
#  'cabbage014.jpg',
#  'cabbage015.jpg',
#  'cabbage016.jpg',
#  'cabbage017.jpg',
#  'cabbage018.jpg',
#  'cabbage019.jpg',
#  'cabbage020.jpg',
#  'cabbage021.jpg',
#  'cabbage022.jpg',
#  'cabbage023.jpg',
#  'cabbage024.jpg',
#  'cabbage025.jpg',
#  'cabbage026.jpg',
#  'cabbage027.jpg',
#  'cabbage028.jpg',
#  'cabbage029.jpg',
#  'cabbage030.jpg',
#  'cabbage031.jpg',
#  'cabbage032.jpg',
#  'cabbage033.jpg',
#  'cabbage034.jpg',
#  'cabbage035.jpg',
#  'cabbage036.jpg',
#  'cabbage037.jpg',
#  'cabbage038.jpg',
#  'cabbage039.jpg',
#  'cabbage040.jpg',
#  'cabbage041.jpg',
#  'cabbage042.jpg',
#  'cabbage043.jpg',
#  'cabbage044.jpg',
#  'cabbage045.jpg',
#  'cabbage046.jpg',
#  'cabbage047.jpg',
#  'cabbage048.jpg',
#  'cabbage049.jpg',
#  'cabbage050.jpg',
#  'cabbage051.jpg',
#  'cabbage052.jpg',
#  'cabbage053.jpg',
#  'cabbage054.jpg',
#  'cabbage055.jpg',
#  'cabbage056.jpg',
#  'cabbage057.jpg',
#  'cabbage058.jpg',
#  'cabbage059.jpg',
#  'cabbage060.jpg',
#  'cabbage061.jpg',
#  'cabbage062.jpg',
#  'cabbage063.jpg',
#  'cabbage064.jpg',
#  'cabbage065.jpg',
#  'cabbage066.jpg',
#  'cabbage067.jpg',
#  'cabbage068.jpg',
#  'cabbage069.jpg',
#  'cabbage070.jpg',
#  'cabbage071.jpg',
#  'cabbage072.jpg',
#  'cabbage073.jpg',
#  'cabbage074.jpg',
#  'cabbage075.jpg',
#  'cabbage076.jpg',
#  'cabbage077.jpg',
#  'cabbage078.jpg',
#  'cabbage079.jpg',
#  'cabbage080.jpg',
#  'cabbage081.jpg',
#  'cabbage082.jpg',
#  'cabbage083.jpg',
#  'cabbage084.jpg',
#  'cabbage085.jpg',
#  'cabbage086.jpg',
#  'cabbage087.jpg',
#  'cabbage088.jpg',
#  'cabbage089.jpg',
#  'cabbage090.jpg',
#  'cabbage091.jpg',
#  'cabbage092.jpg',
#  'cabbage093.jpg',
#  'cabbage094.jpg',
#  'cabbage095.jpg',
#  'cabbage096.jpg',
#  'cabbage097.jpg',
#  'cabbage098.jpg',
#  'cabbage099.jpg',
#  'cabbage100.jpg',
#  'cabbage101.jpg',
#  'cabbage102.jpg',
#  'cabbage103.jpg',
#  'cabbage104.jpg',
#  'cabbage105.jpg',
#  'cabbage106.jpg',
#  'cabbage107.jpg',
#  'cabbage108.jpg',
#  'cabbage109.jpg',
#  'cabbage110.jpg',
#  'cabbage111.jpg',
#  'cabbage112.jpg',
#  'cabbage113.jpg',
#  'cabbage114.jpg',
#  'cabbage115.jpg',
#  'cabbage116.jpg',
#  'cabbage117.jpg',
#  'cabbage118.jpg',
#  'cabbage119.jpg',
#  'cabbage120.jpg',
#  'cabbage121.jpg',
#  'cabbage122.jpg',
#  'cabbage123.jpg',
#  'cabbage124.jpg',
#  'cucumber000.jpg',
#  'cucumber001.jpg',
#  'cucumber002.jpg',
#  'cucumber003.jpg',
#  'cucumber004.jpg',
#  'cucumber005.jpg',
#  'cucumber006.jpg',
#  'cucumber007.jpg',
#  'cucumber008.jpg',
#  'cucumber009.jpg',
#  'cucumber010.jpg',
#  'cucumber011.jpg',
#  'cucumber012.jpg',
#  'cucumber013.jpg',
#  'cucumber014.jpg',
#  'cucumber015.jpg',
#  'cucumber016.jpg',
#  'cucumber017.jpg',
#  'cucumber018.jpg',
#  'cucumber019.jpg',
#  'cucumber020.jpg',
#  'cucumber021.jpg',
#  'cucumber022.jpg',
#  'cucumber023.jpg',
#  'cucumber024.jpg',
#  'cucumber025.jpg',
#  'cucumber026.jpg',
#  'cucumber027.jpg',
#  'cucumber028.jpg',
#  'cucumber029.jpg',
#  'cucumber030.jpg',
#  'cucumber031.jpg',
#  'cucumber032.jpg',
#  'cucumber033.jpg',
#  'cucumber034.jpg',
#  'cucumber035.jpg',
#  'cucumber036.jpg',
#  'cucumber037.jpg',
#  'cucumber038.jpg',
#  'cucumber039.jpg',
#  'cucumber040.jpg',
#  'cucumber041.jpg',
#  'cucumber042.jpg',
#  'cucumber043.jpg',
#  'cucumber044.jpg',
#  'cucumber045.jpg',
#  'cucumber046.jpg',
#  'cucumber047.jpg',
#  'cucumber048.jpg',
#  'cucumber049.jpg',
#  'cucumber050.jpg',
#  'cucumber051.jpg',
#  'cucumber052.jpg',
#  'cucumber053.jpg',
#  'cucumber054.jpg',
#  'cucumber055.jpg',
#  'cucumber056.jpg',
#  'cucumber057.jpg',
#  'cucumber058.jpg',
#  'cucumber059.jpg',
#  'cucumber060.jpg',
#  'cucumber061.jpg',
#  'cucumber062.jpg',
#  'cucumber063.jpg',
#  'cucumber064.jpg',
#  'cucumber065.jpg',
#  'cucumber066.jpg',
#  'cucumber067.jpg',
#  'cucumber068.jpg',
#  'cucumber069.jpg',
#  'cucumber070.jpg',
#  'cucumber071.jpg',
#  'cucumber072.jpg',
#  'cucumber073.jpg',
#  'cucumber074.jpg',
#  'cucumber075.jpg',
#  'cucumber076.jpg',
#  'cucumber077.jpg',
#  'cucumber078.jpg',
#  'cucumber079.jpg',
#  'cucumber080.jpg',
#  'cucumber081.jpg',
#  'cucumber082.jpg',
#  'cucumber083.jpg',
#  'cucumber084.jpg',
#  'cucumber085.jpg',
#  'cucumber086.jpg',
#  'cucumber087.jpg',
#  'cucumber088.jpg',
#  'cucumber089.jpg',
#  'cucumber090.jpg',
#  'cucumber091.jpg',
#  'cucumber092.jpg',
#  'cucumber093.jpg',
#  'cucumber094.jpg',
#  'cucumber095.jpg',
#  'cucumber096.jpg',
#  'cucumber097.jpg',
#  'cucumber098.jpg',
#  'cucumber099.jpg',
#  'cucumber100.jpg',
#  'cucumber101.jpg',
#  'cucumber102.jpg',
#  'cucumber103.jpg',
#  'cucumber104.jpg',
#  'cucumber105.jpg',
#  'cucumber106.jpg',
#  'cucumber107.jpg',
#  'cucumber108.jpg',
#  'cucumber109.jpg',
#  'cucumber110.jpg',
#  'cucumber111.jpg',
#  'cucumber112.jpg',
#  'cucumber113.jpg',
#  'cucumber114.jpg',
#  'cucumber115.jpg',
#  'cucumber116.jpg',
#  'cucumber117.jpg',
#  'cucumber118.jpg',
#  'cucumber119.jpg',
#  'cucumber120.jpg',
#  'cucumber121.jpg',
#  'cucumber122.jpg',
#  'cucumber123.jpg',
#  'cucumber124.jpg',
#  'eggnog000.jpg',
#  'eggnog001.jpg',
#  'eggnog002.jpg',
#  'eggnog003.jpg',
#  'eggnog004.jpg',
#  'eggnog005.jpg',
#  'eggnog006.jpg',
#  'eggnog007.jpg',
#  'eggnog008.jpg',
#  'eggnog009.jpg',
#  'eggnog010.jpg',
#  'eggnog011.jpg',
#  'eggnog012.jpg',
#  'eggnog013.jpg',
#  'eggnog014.jpg',
#  'eggnog015.jpg',
#  'eggnog016.jpg',
#  'eggnog017.jpg',
#  'eggnog018.jpg',
#  'eggnog019.jpg',
#  'eggnog020.jpg',
#  'eggnog021.jpg',
#  'eggnog022.jpg',
#  'eggnog023.jpg',
#  'eggnog024.jpg',
#  'eggnog025.jpg',
#  'eggnog026.jpg',
#  'eggnog027.jpg',
#  'eggnog028.jpg',
#  'eggnog029.jpg',
#  'eggnog030.jpg',
#  'eggnog031.jpg',
#  'eggnog032.jpg',
#  'eggnog033.jpg',
#  'eggnog034.jpg',
#  'eggnog035.jpg',
#  'eggnog036.jpg',
#  'eggnog037.jpg',
#  'eggnog038.jpg',
#  'eggnog039.jpg',
#  'eggnog040.jpg',
#  'eggnog041.jpg',
#  'eggnog042.jpg',
#  'eggnog043.jpg',
#  'eggnog044.jpg',
#  'eggnog045.jpg',
#  'eggnog046.jpg',
#  'eggnog047.jpg',
#  'eggnog048.jpg',
#  'eggnog049.jpg',
#  'eggnog050.jpg',
#  'eggnog051.jpg',
#  'eggnog052.jpg',
#  'eggnog053.jpg',
#  'eggnog054.jpg',
#  'eggnog055.jpg',
#  'eggnog056.jpg',
#  'eggnog057.jpg',
#  'eggnog058.jpg',
#  'eggnog059.jpg',
#  'eggnog060.jpg',
#  'eggnog061.jpg',
#  'eggnog062.jpg',
#  'eggnog063.jpg',
#  'eggnog064.jpg',
#  'eggnog065.jpg',
#  'eggnog066.jpg',
#  'eggnog067.jpg',
#  'eggnog068.jpg',
#  'eggnog069.jpg',
#  'eggnog070.jpg',
#  'eggnog071.jpg',
#  'eggnog072.jpg',
#  'eggnog073.jpg',
#  'eggnog074.jpg',
#  'eggnog075.jpg',
#  'eggnog076.jpg',
#  'eggnog077.jpg',
#  'eggnog078.jpg',
#  'eggnog079.jpg',
#  'eggnog080.jpg',
#  'eggnog081.jpg',
#  'eggnog082.jpg',
#  'eggnog083.jpg',
#  'eggnog084.jpg',
#  'eggnog085.jpg',
#  'eggnog086.jpg',
#  'eggnog087.jpg',
#  'eggnog088.jpg',
#  'eggnog089.jpg',
#  'eggnog090.jpg',
#  'eggnog091.jpg',
#  'eggnog092.jpg',
#  'eggnog093.jpg',
#  'eggnog094.jpg',
#  'eggnog095.jpg',
#  'eggnog096.jpg',
#  'eggnog097.jpg',
#  'eggnog098.jpg',
#  'eggnog099.jpg',
#  'eggnog100.jpg',
#  'eggnog101.jpg',
#  'eggnog102.jpg',
#  'eggnog103.jpg',
#  'eggnog104.jpg',
#  'eggnog105.jpg',
#  'eggnog106.jpg',
#  'eggnog107.jpg',
#  'eggnog108.jpg',
#  'eggnog109.jpg',
#  'eggnog110.jpg',
#  'eggnog111.jpg',
#  'eggnog112.jpg',
#  'eggnog113.jpg',
#  'eggnog114.jpg',
#  'eggnog115.jpg',
#  'eggnog116.jpg',
#  'eggnog117.jpg',
#  'eggnog118.jpg',
#  'eggnog119.jpg',
#  'eggnog120.jpg',
#  'eggnog121.jpg',
#  'eggnog122.jpg',
#  'eggnog123.jpg',
#  'eggnog124.jpg',
#  'hotdog000.jpg',
#  'hotdog001.jpg',
#  'hotdog002.jpg',
#  'hotdog003.jpg',
#  'hotdog004.jpg',
#  'hotdog005.jpg',
#  'hotdog006.jpg',
#  'hotdog007.jpg',
#  'hotdog008.jpg',
#  'hotdog009.jpg',
#  'hotdog010.jpg',
#  'hotdog011.jpg',
#  'hotdog012.jpg',
#  'hotdog013.jpg',
#  'hotdog014.jpg',
#  'hotdog015.jpg',
#  'hotdog016.jpg',
#  'hotdog017.jpg',
#  'hotdog018.jpg',
#  'hotdog019.jpg',
#  'hotdog020.jpg',
#  'hotdog021.jpg',
#  'hotdog022.jpg',
#  'hotdog023.jpg',
#  'hotdog024.jpg',
#  'hotdog025.jpg',
#  'hotdog026.jpg',
#  'hotdog027.jpg',
#  'hotdog028.jpg',
#  'hotdog029.jpg',
#  'hotdog030.jpg',
#  'hotdog031.jpg',
#  'hotdog032.jpg',
#  'hotdog033.jpg',
#  'hotdog034.jpg',
#  'hotdog035.jpg',
#  'hotdog036.jpg',
#  'hotdog037.jpg',
#  'hotdog038.jpg',
#  'hotdog039.jpg',
#  'hotdog040.jpg',
#  'hotdog041.jpg',
#  'hotdog042.jpg',
#  'hotdog043.jpg',
#  'hotdog044.jpg',
#  'hotdog045.jpg',
#  'hotdog046.jpg',
#  'hotdog047.jpg',
#  'hotdog048.jpg',
#  'hotdog049.jpg',
#  'hotdog050.jpg',
#  'hotdog051.jpg',
#  'hotdog052.jpg',
#  'hotdog053.jpg',
#  'hotdog054.jpg',
#  'hotdog055.jpg',
#  'hotdog056.jpg',
#  'hotdog057.jpg',
#  'hotdog058.jpg',
#  'hotdog059.jpg',
#  'hotdog060.jpg',
#  'hotdog061.jpg',
#  'hotdog062.jpg',
#  'hotdog063.jpg',
#  'hotdog064.jpg',
#  'hotdog065.jpg',
#  'hotdog066.jpg',
#  'hotdog067.jpg',
#  'hotdog068.jpg',
#  'hotdog069.jpg',
#  'hotdog070.jpg',
#  'hotdog071.jpg',
#  'hotdog072.jpg',
#  'hotdog073.jpg',
#  'hotdog074.jpg',
#  'hotdog075.jpg',
#  'hotdog076.jpg',
#  'hotdog077.jpg',
#  'hotdog078.jpg',
#  'hotdog079.jpg',
#  'hotdog080.jpg',
#  'hotdog081.jpg',
#  'hotdog082.jpg',
#  'hotdog083.jpg',
#  'hotdog084.jpg',
#  'hotdog085.jpg',
#  'hotdog086.jpg',
#  'hotdog087.jpg',
#  'hotdog088.jpg',
#  'hotdog089.jpg',
#  'hotdog090.jpg',
#  'hotdog091.jpg',
#  'hotdog092.jpg',
#  'hotdog093.jpg',
#  'hotdog094.jpg',
#  'hotdog095.jpg',
#  'hotdog096.jpg',
#  'hotdog097.jpg',
#  'hotdog098.jpg',
#  'hotdog099.jpg',
#  'hotdog100.jpg',
#  'hotdog101.jpg',
#  'hotdog102.jpg',
#  'hotdog103.jpg',
#  'hotdog104.jpg',
#  'hotdog105.jpg',
#  'hotdog106.jpg',
#  'hotdog107.jpg',
#  'hotdog108.jpg',
#  'hotdog109.jpg',
#  'hotdog110.jpg',
#  'hotdog111.jpg',
#  'hotdog112.jpg',
#  'hotdog113.jpg',
#  'hotdog114.jpg',
#  'hotdog115.jpg',
#  'hotdog116.jpg',
#  'hotdog117.jpg',
#  'hotdog118.jpg',
#  'hotdog119.jpg',
#  'hotdog120.jpg',
#  'hotdog121.jpg',
#  'hotdog122.jpg',
#  'hotdog123.jpg',
#  ...]

# %% [markdown]
# ### Start implementing Base Neural Network

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# !pip install scikit-learn
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\charl\miniforge3\lib\site-packages (2.9.1+cpu)
# Requirement already satisfied: torchvision in c:\users\charl\miniforge3\lib\site-packages (0.24.1+cpu)
# Requirement already satisfied: filelock in c:\users\charl\miniforge3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\charl\miniforge3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\charl\miniforge3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\charl\miniforge3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\charl\miniforge3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\charl\miniforge3\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\charl\miniforge3\lib\site-packages (from torch) (75.6.0)
# Requirement already satisfied: numpy in c:\users\charl\miniforge3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\charl\miniforge3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\charl\miniforge3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\charl\miniforge3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: scikit-learn in c:\users\charl\miniforge3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\charl\miniforge3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\charl\miniforge3\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\charl\miniforge3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\charl\miniforge3\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from io import BytesIO
import numpy as np
from tqdm import tqdm
import pandas as pd
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
classes = sorted(list(set([name[:-7] for name in all_images])))
print(f"Found {len(all_images)} images across {len(classes)} classes.")
print(classes)
# Out:
# Found 2502 images across 20 classes.
# ['bagel', 'banana', 'broccoli', 'burrito', 'cabbage', 'cucumber', 'eggnog', 'hotdog', 'ice_cream', 'jackfruit', 'lemon', 'mashed_potato', 'meat_loaf', 'mushroom', 'pineapple', 'pizza', 'pomegranate', 'potpie', 'pretzel', 'strawberry']

# %%
# Map each class to numbers for neural network training:
classtoidx = {c:i for i,c in enumerate(classes)}
idxtoclass = {i:c for c,i in classtoidx.items()}

samples = []
for name in all_images:
    clas = name[:-7]
    if clas not in classtoidx:
        continue
    path = os.path.join(image_dir, name)
    samples.append((path, classtoidx[clas]))
print("Example sample:", samples[:3])
# Out:
# Example sample: [('data/bagel000.jpg', 0), ('data/bagel001.jpg', 0), ('data/bagel002.jpg', 0)]

# %%
# Prep data:
class FoodDataset(Dataset):
    def __init__(self, img_paths, labels, transform=None):
        self.img_paths = img_paths
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.img_paths)
    
    def __getitem__(self, idx):
        img = Image.open(self.img_paths[idx]).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

def load_food_data(image_dir):
    all_images = [x for x in os.listdir(image_dir) if x.endswith('.jpg')]
    img_paths = []
    labels = []
    
    classes = sorted(list(set([name[:-7] for name in all_images])))
    print(f"Found {len(all_images)} images across {len(classes)} classes.")
    print(classes)
    
    classtoidx = {clas: idx for idx, clas in enumerate(classes)}
    for filename in all_images:
        img_paths.append(os.path.join(image_dir, filename))
        class_name = ''.join([c for c in os.path.splitext(filename)[0] if c.isalpha() or c == '_'])
        labels.append(classtoidx[class_name])
    
    split = int(0.8 * len(img_paths)) # 80/20 split of train and test data
    indices = np.random.permutation(len(img_paths))
    
    train_paths = [img_paths[i] for i in indices[:split]]
    train_labels = [labels[i] for i in indices[:split]]
    test_paths = [img_paths[i] for i in indices[split:]]
    test_labels = [labels[i] for i in indices[split:]]
    
    return train_paths, train_labels, test_paths, test_labels, classes

# %%
# Data transformation:
transform = transforms.Compose([
    transforms.Resize((256, 256)), # Matches pixels of images we are using
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

image_dir = "data/"
train_paths, train_labels, test_paths, test_labels, classes = load_food_data(image_dir)

batch_size = 20
trainset = FoodDataset(train_paths, train_labels, transform=transform)
testset = FoodDataset(test_paths, test_labels, transform=transform)
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=0)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=0)
# Out:
# Found 2502 images across 20 classes.
# ['bagel', 'banana', 'broccoli', 'burrito', 'cabbage', 'cucumber', 'eggnog', 'hotdog', 'ice_cream', 'jackfruit', 'lemon', 'mashed_potato', 'meat_loaf', 'mushroom', 'pineapple', 'pizza', 'pomegranate', 'potpie', 'pretzel', 'strawberry']

# %%
# Implement Neural Network:
class Net(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 61 * 61, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, num_classes)
    
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Train the Neural Network:
model = Net(num_classes=len(classes))
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

EPOCHS = 20
train_accuracies = []
test_accuracies = []
train_losses = []
print("Training...")

for epoch in range(EPOCHS):
    model.train()
    running_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for i, data in enumerate(tqdm(trainloader, desc=f"Epoch {epoch + 1} of {EPOCHS}", leave=True, ncols=80)):
        inputs, labels_batch = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs, 1)
        train_total += labels_batch.size(0)
        train_correct += (predicted == labels_batch).sum().item()
    
    epoch_loss = running_loss / len(trainloader)
    train_accuracy = 100 * train_correct / train_total
    train_losses.append(epoch_loss)
    train_accuracies.append(train_accuracy)
    
    # Test the model:
    model.eval()
    test_correct = 0
    test_total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels_batch = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            test_total += labels_batch.size(0)
            test_correct += (predicted == labels_batch).sum().item()
    
    test_accuracy = 100 * test_correct / test_total
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}, Loss: {epoch_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, Test Accuracy: {test_accuracy:.2f}%")

path = './food_net.pth'
torch.save(model.state_dict(), path)
print(f"Model saved to {path}")
# Out:
# Training...
# Epoch 1 of 20: 100%|██████████████████████████| 101/101 [00:09<00:00, 10.54it/s]
# Epoch 1, Loss: 2.9892, Train Accuracy: 6.85%, Test Accuracy: 8.58%
# Epoch 2 of 20: 100%|██████████████████████████| 101/101 [00:10<00:00,  9.56it/s]
# Epoch 2, Loss: 2.9331, Train Accuracy: 10.94%, Test Accuracy: 15.17%
# Epoch 3 of 20: 100%|██████████████████████████| 101/101 [00:11<00:00,  8.63it/s]
# Epoch 3, Loss: 2.7034, Train Accuracy: 15.14%, Test Accuracy: 19.36%
# Epoch 4 of 20: 100%|██████████████████████████| 101/101 [00:11<00:00,  8.75it/s]
# Epoch 4, Loss: 2.5044, Train Accuracy: 20.39%, Test Accuracy: 18.36%
# Epoch 5 of 20: 100%|██████████████████████████| 101/101 [00:10<00:00,  9.36it/s]
# Epoch 5, Loss: 2.4145, Train Accuracy: 24.99%, Test Accuracy: 20.16%
# Epoch 6 of 20: 100%|██████████████████████████| 101/101 [00:11<00:00,  8.98it/s]
# Epoch 6, Loss: 2.2790, Train Accuracy: 27.74%, Test Accuracy: 22.95%
# Epoch 7 of 20: 100%|██████████████████████████| 101/101 [00:10<00:00,  9.19it/s]
# Epoch 7, Loss: 2.1935, Train Accuracy: 31.13%, Test Accuracy: 22.95%
# Epoch 8 of 20: 100%|██████████████████████████| 101/101 [00:11<00:00,  9.00it/s]
# Epoch 8, Loss: 2.0557, Train Accuracy: 35.53%, Test Accuracy: 22.16%
# Epoch 9 of 20: 100%|██████████████████████████| 101/101 [00:10<00:00,  9.20it/s]
# Epoch 9, Loss: 1.9414, Train Accuracy: 38.28%, Test Accuracy: 25.35%
# Epoch 10 of 20: 100%|█████████████████████████| 101/101 [00:10<00:00,  9.22it/s]
# Epoch 10, Loss: 1.7647, Train Accuracy: 44.03%, Test Accuracy: 24.15%
# Epoch 11 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.77it/s]
# Epoch 11, Loss: 1.6187, Train Accuracy: 49.38%, Test Accuracy: 21.56%
# Epoch 12 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.88it/s]
# Epoch 12, Loss: 1.5407, Train Accuracy: 51.17%, Test Accuracy: 25.95%
# Epoch 13 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.73it/s]
# Epoch 13, Loss: 1.2326, Train Accuracy: 61.37%, Test Accuracy: 26.35%
# Epoch 14 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.58it/s]
# Epoch 14, Loss: 1.0357, Train Accuracy: 66.57%, Test Accuracy: 22.75%
# Epoch 15 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.66it/s]
# Epoch 15, Loss: 0.7744, Train Accuracy: 75.36%, Test Accuracy: 26.15%
# Epoch 16 of 20: 100%|█████████████████████████| 101/101 [00:12<00:00,  8.21it/s]
# Epoch 16, Loss: 0.6064, Train Accuracy: 80.56%, Test Accuracy: 25.15%
# Epoch 17 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  8.55it/s]
# Epoch 17, Loss: 0.6681, Train Accuracy: 78.76%, Test Accuracy: 25.35%
# Epoch 18 of 20: 100%|█████████████████████████| 101/101 [00:12<00:00,  8.08it/s]
# Epoch 18, Loss: 0.3176, Train Accuracy: 90.55%, Test Accuracy: 26.15%
# Epoch 19 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  9.03it/s]
# Epoch 19, Loss: 0.4617, Train Accuracy: 86.61%, Test Accuracy: 21.36%
# Epoch 20 of 20: 100%|█████████████████████████| 101/101 [00:11<00:00,  9.16it/s]
# Epoch 20, Loss: 0.9322, Train Accuracy: 74.56%, Test Accuracy: 26.55%
# Model saved to ./food_net.pth

# %%
# Test Trained Neural Network Model:
dataiter = iter(testloader)
images, labels_batch = next(dataiter)

model = Net(num_classes=len(classes))
model.load_state_dict(torch.load(path))
model.eval()

# Make predictions
with torch.no_grad():
    outputs = model(images)
    _, predicted = torch.max(outputs, 1)

# Visualize predictions
plt.figure(figsize=(15, 6))
for i in range(min(batch_size, len(images))):
    plt.subplot(2, int(batch_size/2), i + 1)
    img = images[i]
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    
    color = "green" # good/correct
    label = classes[predicted[i]]
    if classes[labels_batch[i]] != classes[predicted[i]]:
        color = "red" #bad/wrong
        label = "(" + label + ")"
    plt.title(label, color=color)

plt.suptitle('Images Found by Model', size=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Accuracy Check

# %%
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

with torch.no_grad():
    for data in testloader:
        images, labels_batch = data
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)
        for label, prediction in zip(labels_batch, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1

# accuracy stats:
print("\n" + "="*50)
print("ACCURACY BY CLASS")
print("="*50)
test_correct = 0
test_total = 0
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:15s} is {accuracy:.1f}%')
    test_correct += correct_count
    test_total += total_pred[classname]

test_accuracy = 100 * float(test_correct) / test_total
train_accuracy = 100 * train_correct / train_total
print("="*50)
print(f'Test Accuracy: {test_accuracy:.1f}%')
print("="*50)
print(f'Training Accuracy: {train_accuracy:.1f}%')
# Out:
# ==================================================
# ACCURACY BY CLASS
# ==================================================
# Accuracy for class: bagel           is 26.3%
# Accuracy for class: banana          is 23.1%
# Accuracy for class: broccoli        is 21.4%
# Accuracy for class: burrito         is 4.2%
# Accuracy for class: cabbage         is 40.9%
# Accuracy for class: cucumber        is 9.4%
# Accuracy for class: eggnog          is 20.0%
# Accuracy for class: hotdog          is 15.0%
# Accuracy for class: ice_cream       is 0.0%
# Accuracy for class: jackfruit       is 70.0%
# Accuracy for class: lemon           is 50.0%
# Accuracy for class: mashed_potato   is 37.5%
# Accuracy for class: meat_loaf       is 42.3%
# Accuracy for class: mushroom        is 40.0%
# Accuracy for class: pineapple       is 20.0%
# Accuracy for class: pizza           is 20.7%
# Accuracy for class: pomegranate     is 31.8%
# Accuracy for class: potpie          is 9.5%
# Accuracy for class: pretzel         is 8.3%
# Accuracy for class: strawberry      is 53.6%
# ==================================================
# Test Accuracy: 26.5%
# ==================================================
# Training Accuracy: 74.6%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
epochs_range = range(1, EPOCHS + 1)
ax1.plot(epochs_range, train_accuracies, 'b', label='Training Accuracy', linewidth=2)
ax1.plot(epochs_range, test_accuracies, 'r', label='Testing Accuracy', linewidth=2)
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Accuracy (%)', fontsize=12)
ax1.set_title('Training vs Testing Accuracy per Epoch', fontsize=14, fontweight='bold')
ax1.legend(fontsize=11)
ax1.grid(True, alpha=0.3)
ax1.set_ylim([0, 100])
ax2.plot(epochs_range, train_losses, 'g', label='Training Loss', linewidth=2)
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Loss', fontsize=12)
ax2.set_title('Training Loss Over Time', fontsize=14, fontweight='bold')
ax2.legend(fontsize=11)
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Confusion Matrix:
all_predictions = []
all_labels = []

model.eval()
with torch.no_grad():
    for data in testloader:
        images, labels_batch = data
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)
        all_predictions.extend(predictions.cpu().numpy())
        all_labels.extend(labels_batch.cpu().numpy())

cm = confusion_matrix(all_labels, all_predictions)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=classes, yticklabels=classes,
            cbar_kws={'label': 'Number of Predictions'})
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.title('Confusion Matrix Base Neural Network', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
